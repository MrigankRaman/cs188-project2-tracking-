# %%
# %run  -m doctest -v inference.py
# Out:
# Trying:
#     dist = DiscreteDistribution()
# Expecting nothing
# ok
# Trying:
#     dist['a'] = 1
# Expecting nothing
# ok
# Trying:
#     dist['b'] = 2
# Expecting nothing
# ok
# Trying:
#     dist['c'] = 2
# Expecting nothing
# ok
# Trying:
#     dist['d'] = 0
# Expecting nothing
# ok
# Trying:
#     dist.normalize()
# Expecting nothing
# ok
# Trying:
#     list(sorted(dist.items()))
# Expecting:
#     [('a', 0.2), ('b', 0.4), ('c', 0.4), ('d', 0.0)]
# ok
# Trying:
#     dist['e'] = 4
# Expecting nothing
# ok
# Trying:
#     list(sorted(dist.items()))
# Expecting:
#     [('a', 0.2), ('b', 0.4), ('c', 0.4), ('d', 0.0), ('e', 4)]
# ok
# Trying:
#     empty = DiscreteDistribution()
# Expecting nothing
# ok
# Trying:
#     empty.normalize()
# Expecting nothing
# ok
# Trying:
#     empty
# Expecting:
#     {}
# ok
# Trying:
#     dist = DiscreteDistribution()
# Expecting nothing
# ok
# Trying:
#     dist['a'] = 1
# Expecting nothing
# ok
# Trying:
#     dist['b'] = 2
# ...

# %%
# %run autograder.py -q q1
# Out:
# Starting on 6-25 at 0:36:05
#
# Question q1
# ...
# *** PASS: test_cases\q1\1-ObsProb.test
# *** 	PASS
#
# ### Question q1: 2/2 ###
#
#
# Finished at 0:36:05
#
# Provisional grades
# ...
# Question q1: 2/2
# ------------------
# Total: 2/2
#
# Your grades are NOT yet registered.  To register your grades, make sure
# to follow your instructor's guidelines to receive credit on your project.

# %%
# %run autograder.py -q q2 --no-graphics
# Out:
# Starting on 6-25 at 0:54:50
#
# Question q2
# ...
# *** q2) Exact inference stationary pacman observe test: 0 inference errors.
# *** PASS: test_cases\q2\1-ExactUpdate.test
# *** q2) Exact inference stationary pacman observe test: 0 inference errors.
# *** PASS: test_cases\q2\2-ExactUpdate.test
# *** q2) Exact inference stationary pacman observe test: 0 inference errors.
# *** PASS: test_cases\q2\3-ExactUpdate.test
# *** q2) Exact inference stationary pacman observe test: 0 inference errors.
# *** PASS: test_cases\q2\4-ExactUpdate.test
#
# ### Question q2: 3/3 ###
#
#
# Finished at 0:54:50
#
# Provisional grades
# ...
# Question q2: 3/3
# ------------------
# Total: 3/3
#
# Your grades are NOT yet registered.  To register your grades, make sure
# to follow your instructor's guidelines to receive credit on your project.

# %%
# %run autograder.py -q q3 --no-graphics
# Out:
# Starting on 6-25 at 1:13:34
#
# Question q3
# ...
# *** q3) Exact inference elapseTime test: 0 inference errors.
# *** PASS: test_cases\q3\1-ExactPredict.test
# *** q3) Exact inference elapseTime test: 0 inference errors.
# *** PASS: test_cases\q3\2-ExactPredict.test
# *** q3) Exact inference elapseTime test: 0 inference errors.
# *** PASS: test_cases\q3\3-ExactPredict.test
# *** q3) Exact inference elapseTime test: 0 inference errors.
# *** PASS: test_cases\q3\4-ExactPredict.test
#
# ### Question q3: 3/3 ###
#
#
# Finished at 1:14:13
#
# Provisional grades
# ...
# Question q3: 3/3
# ------------------
# Total: 3/3
#
# Your grades are NOT yet registered.  To register your grades, make sure
# to follow your instructor's guidelines to receive credit on your project.

# %%
# %run autograder.py -q q4 --no-graphics
# Out:
# Starting on 6-25 at 10:49:00
#
# Question q4
# ...
# *** q4) Exact inference full test: 0 inference errors.
# *** PASS: test_cases\q4\1-ExactFull.test
# *** q4) Exact inference full test: 0 inference errors.
# *** PASS: test_cases\q4\2-ExactFull.test
# ExactInference
# [Distancer]: Switching to maze distances
# Average Score: 749.4
# Scores:        761, 769, 763, 756, 736, 725, 769, 716, 767, 732
# Win Rate:      10/10 (1.00)
# Record:        Win, Win, Win, Win, Win, Win, Win, Win, Win, Win
# *** Won 10 out of 10 games. Average score: 749.400000 ***
# *** smallHunt) Games won on q4 with score above 700: 10/10
# *** PASS: test_cases\q4\3-gameScoreTest.test
#
# ### Question q4: 2/2 ###
#
#
# Finished at 10:49:40
#
# Provisional grades
# ...
# Question q4: 2/2
# ------------------
# Total: 2/2
#
# Your grades are NOT yet registered.  To register your grades, make sure
# to follow your instructor's guidelines to receive credit on your project.

# %%
# %run autograder.py -q q5 --no-graphics
# Out:
# Starting on 6-25 at 17:43:48
#
# Question q5
# ...
# *** q5) Particle filter initialization test: 0 inference errors.
# *** PASS: test_cases\q5\1-ParticleInit.test
#
# ### Question q5: 2/2 ###
#
#
# Finished at 17:43:48
#
# Provisional grades
# ...
# Question q5: 2/2
# ------------------
# Total: 2/2
#
# Your grades are NOT yet registered.  To register your grades, make sure
# to follow your instructor's guidelines to receive credit on your project.

# %%
# %run autograder.py -q q6 --no-graphics
# Out:
# Starting on 6-25 at 17:41:52
#
# Question q6
# ...
# *** q6) Particle filter observe test: 0 inference errors.
# *** PASS: test_cases\q6\1-ParticleUpdate.test
# *** q6) Particle filter observe test: 0 inference errors.
# *** PASS: test_cases\q6\2-ParticleUpdate.test
# *** q6) Particle filter observe test: 0 inference errors.
# *** PASS: test_cases\q6\3-ParticleUpdate.test
# *** q6) Particle filter observe test: 0 inference errors.
# *** PASS: test_cases\q6\4-ParticleUpdate.test
# *** q6) successfully handled all weights = 0
# *** PASS: test_cases\q6\5-ParticleUpdate.test
# ParticleFilter
# [Distancer]: Switching to maze distances
# Average Score: 185.4
# Scores:        194, 167, 195, 196, 184, 187, 182, 171, 192, 186
# Win Rate:      10/10 (1.00)
# Record:        Win, Win, Win, Win, Win, Win, Win, Win, Win, Win
# *** Won 10 out of 10 games. Average score: 185.400000 ***
# *** oneHunt) Games won on q6 with score above 100: 10/10
# *** PASS: test_cases\q6\6-ParticleUpdate.test
#
# ...

# %%
# %run autograder.py -q q7 --no-graphics
# Out:
# Starting on 6-25 at 18:04:34
#
# Question q7
# ...
# *** q7) Particle filter full test: 0 inference errors.
# *** PASS: test_cases\q7\1-ParticlePredict.test
# *** q7) Particle filter full test: 0 inference errors.
# *** PASS: test_cases\q7\2-ParticlePredict.test
# *** q7) Particle filter full test: 0 inference errors.
# *** PASS: test_cases\q7\3-ParticlePredict.test
# *** q7) Particle filter full test: 0 inference errors.
# *** PASS: test_cases\q7\4-ParticlePredict.test
# *** q7) Particle filter full test: 0 inference errors.
# *** PASS: test_cases\q7\5-ParticlePredict.test
# ParticleFilter
# [Distancer]: Switching to maze distances
# Average Score: 381.4
# Scores:        386, 377, 379, 380, 385
# Win Rate:      5/5 (1.00)
# Record:        Win, Win, Win, Win, Win
# *** Won 5 out of 5 games. Average score: 381.400000 ***
# *** smallHunt) Games won on q7 with score above 300: 5/5
# *** PASS: test_cases\q7\6-ParticlePredict.test
#
# ### Question q7: 3/3 ###
#
#
# Finished at 18:09:26
#
# ...

# %%
# %run autograder.py -q q8 --no-graphics
# Out:
# Starting on 6-25 at 19:09:53
#
# Question q8
# ...
# *** q8) Joint particle filter initialization test: 0 inference errors.
# *** PASS: test_cases\q8\1-JointParticleInit.test
#
# ### Question q8: 1/1 ###
#
#
# Finished at 19:09:53
#
# Provisional grades
# ...
# Question q8: 1/1
# ------------------
# Total: 1/1
#
# Your grades are NOT yet registered.  To register your grades, make sure
# to follow your instructor's guidelines to receive credit on your project.

# %%
# %run autograder.py -q q9 --no-graphics
# Out:
# Starting on 6-25 at 19:32:41
#
# Question q9
# ...
# *** q9) Joint particle filter observeUpdate test: 0 inference errors.
# *** PASS: test_cases\q9\1-JointParticleUpdate.test
# *** q9) Joint particle filter observeUpdate test: 0 inference errors.
# *** PASS: test_cases\q9\2-JointParticleUpdate.test
# *** q9) successfully handled all weights = 0
# *** PASS: test_cases\q9\3-JointParticleUpdate.test
# *** q9) Joint particle filter observeUpdate test: 0 inference errors.
# *** PASS: test_cases\q9\4-JointParticleUpdate.test
#
# ### Question q9: 3/3 ###
#
#
# Finished at 19:34:15
#
# Provisional grades
# ...
# Question q9: 3/3
# ------------------
# Total: 3/3
#
# Your grades are NOT yet registered.  To register your grades, make sure
# to follow your instructor's guidelines to receive credit on your project.

# %%
# %run autograder.py -q q10 --no-graphics
# Out:
# Starting on 6-25 at 20:50:23
#
# Question q10
# ...
# *** q10) Joint particle filter elapseTime test: 0 inference errors.
# *** PASS: test_cases\q10\1-JointParticlePredict.test
# *** q10) Joint particle filter elapseTime test: 0 inference errors.
# *** PASS: test_cases\q10\2-JointParticlePredict.test
# *** q10) Joint particle filter elapseTime test: 0 inference errors.
# *** PASS: test_cases\q10\3-JointParticleFull.test
#
# ### Question q10: 3/3 ###
#
#
# Finished at 20:54:35
#
# Provisional grades
# ...
# Question q10: 3/3
# ------------------
# Total: 3/3
#
# Your grades are NOT yet registered.  To register your grades, make sure
# to follow your instructor's guidelines to receive credit on your project.

# %%
# %run autograder.py  --no-graphics
# Out:
# Starting on 6-25 at 20:55:51
#
# Question q1
# ...
# *** PASS: test_cases\q1\1-ObsProb.test
# *** 	PASS
#
# ### Question q1: 2/2 ###
#
#
# Question q2
# ...
# *** q2) Exact inference stationary pacman observe test: 0 inference errors.
# *** PASS: test_cases\q2\1-ExactUpdate.test
# *** q2) Exact inference stationary pacman observe test: 0 inference errors.
# *** PASS: test_cases\q2\2-ExactUpdate.test
# *** q2) Exact inference stationary pacman observe test: 0 inference errors.
# *** PASS: test_cases\q2\3-ExactUpdate.test
# *** q2) Exact inference stationary pacman observe test: 0 inference errors.
# *** PASS: test_cases\q2\4-ExactUpdate.test
#
# ### Question q2: 3/3 ###
#
#
# Question q3
# ...
# *** q3) Exact inference elapseTime test: 0 inference errors.
# *** PASS: test_cases\q3\1-ExactPredict.test
# *** q3) Exact inference elapseTime test: 0 inference errors.
# *** PASS: test_cases\q3\2-ExactPredict.test
# *** q3) Exact inference elapseTime test: 0 inference errors.
# ...
